# %%
import rankine_hugoniot as rh
arh = rh.AnisotropicMHD()
arh.set_param(beta1=0.1)

# %%
arh.solve()
arh.plot()
# Out:
# D:\ProgramData\kx198x\kx198x.github.io\assets\code\20220515\rankine_hugoniot.py:57: RuntimeWarning: invalid value encountered in true_divide
#   self.Mn1m = (Lamb-np.sqrt(Lamb**2-Lama*Lamc))/Lama/self.eps1
# D:\ProgramData\kx198x\kx198x.github.io\assets\code\20220515\rankine_hugoniot.py:58: RuntimeWarning: invalid value encountered in true_divide
#   self.Mn1p = (Lamb+np.sqrt(Lamb**2-Lama*Lamc))/Lama/self.eps1
